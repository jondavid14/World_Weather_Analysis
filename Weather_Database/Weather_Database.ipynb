# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

#Import dependencies
import requests
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 755

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=be5bb21ccc5ac5c7c4e0a22e1540659a

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zhanjiang
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | lata
# Processing Record 4 of Set 1 | lianran
# Processing Record 5 of Set 1 | treinta y tres
# Processing Record 6 of Set 1 | mount isa
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | kaitangata
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | izhma
# Processing Record 13 of Set 1 | skjervoy
# Processing Record 14 of Set 1 | saldanha
# Processing Record 15 of Set 1 | hastings
# Processing Record 16 of Set 1 | buin
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | jambi
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | oranjemund
# Processing Record 23 of Set 1 | turukhansk
# Processing Record 24 of Set 1 | chishtian mandi
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | port augusta
# Processing Record 28 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 1 | hobyo
# Processing Record 30 of Set 1 | chapais
# Processing Record 31 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | camacari
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | terra santa
# Processing Record 37 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 1 | hamza
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | airai
# Processing Record 41 of Set 1 | mongo
# Processing Record 42 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | olafsvik
# Processing Record 49 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 1 | maragogi
# Processing Record 1 of Set 2 | krasnoarmeysk
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | talnakh
# Processing Record 4 of Set 2 | huilong
# Processing Record 5 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 2 | santa rosa
# Processing Record 8 of Set 2 | sale
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | arona
# Processing Record 12 of Set 2 | kudchi
# City not found. Skipping...
# Processing Record 13 of Set 2 | pauini
# Processing Record 14 of Set 2 | knysna
# Processing Record 15 of Set 2 | kuragino
# Processing Record 16 of Set 2 | talcahuano
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | porto velho
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | tuatapere
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | mehriz
# Processing Record 26 of Set 2 | palmer
# Processing Record 27 of Set 2 | sancti spiritus
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | kerema
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | ituporanga
# Processing Record 36 of Set 2 | pochutla
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | ust-tsilma
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | havre-saint-pierre
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | padilla
# Processing Record 45 of Set 2 | tulcingo
# City not found. Skipping...
# Processing Record 46 of Set 2 | bandarbeyla
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | batemans bay
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | zhangjiakou
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 3 | dwarka
# Processing Record 4 of Set 3 | hualmay
# Processing Record 5 of Set 3 | baoying
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | puerto escondido
# Processing Record 8 of Set 3 | tautira
# Processing Record 9 of Set 3 | milingimbi
# City not found. Skipping...
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | pampa
# Processing Record 12 of Set 3 | gladstone
# Processing Record 13 of Set 3 | caravelas
# Processing Record 14 of Set 3 | manavalakurichi
# Processing Record 15 of Set 3 | pangai
# Processing Record 16 of Set 3 | san cristobal
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | mizdah
# Processing Record 20 of Set 3 | bagdarin
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | churapcha
# Processing Record 23 of Set 3 | padang
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | plonsk
# Processing Record 28 of Set 3 | broken hill
# Processing Record 29 of Set 3 | dunedin
# Processing Record 30 of Set 3 | natal
# Processing Record 31 of Set 3 | qui nhon
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | qaqortoq
# Processing Record 34 of Set 3 | kumylzhenskaya
# Processing Record 35 of Set 3 | san andres
# Processing Record 36 of Set 3 | butaritari
# Processing Record 37 of Set 3 | port macquarie
# Processing Record 38 of Set 3 | saskylakh
# Processing Record 39 of Set 3 | valenca
# Processing Record 40 of Set 3 | dalgopol
# Processing Record 41 of Set 3 | praia da vitoria
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | pisco
# Processing Record 44 of Set 3 | kijang
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | ndende
# Processing Record 47 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 3 | miraflores
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | mont-dore
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | roma
# Processing Record 3 of Set 4 | andenes
# Processing Record 4 of Set 4 | ban nahin
# Processing Record 5 of Set 4 | koslan
# Processing Record 6 of Set 4 | henties bay
# Processing Record 7 of Set 4 | georgetown
# Processing Record 8 of Set 4 | teguise
# Processing Record 9 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 4 | polyarnyy
# Processing Record 11 of Set 4 | erenhot
# Processing Record 12 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | villa carlos paz
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | hajipur
# Processing Record 18 of Set 4 | las choapas
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | chiang khong
# Processing Record 22 of Set 4 | bonavista
# Processing Record 23 of Set 4 | hay river
# Processing Record 24 of Set 4 | qasigiannguit
# Processing Record 25 of Set 4 | yulara
# Processing Record 26 of Set 4 | santa marinella
# Processing Record 27 of Set 4 | yeppoon
# Processing Record 28 of Set 4 | cherskiy
# Processing Record 29 of Set 4 | kajaani
# Processing Record 30 of Set 4 | fayaoue
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | santa fe
# Processing Record 33 of Set 4 | brae
# Processing Record 34 of Set 4 | lakeway
# Processing Record 35 of Set 4 | yangjiang
# Processing Record 36 of Set 4 | dicabisagan
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | kamenka
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | aksarka
# Processing Record 41 of Set 4 | falaleu
# City not found. Skipping...
# Processing Record 42 of Set 4 | mitu
# Processing Record 43 of Set 4 | quatre cocos
# Processing Record 44 of Set 4 | lorengau
# Processing Record 45 of Set 4 | sansai
# City not found. Skipping...
# Processing Record 46 of Set 4 | itaituba
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | saint anthony
# Processing Record 49 of Set 4 | lompoc
# Processing Record 50 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 5 | lingyuan
# Processing Record 2 of Set 5 | hami
# Processing Record 3 of Set 5 | coquimbo
# Processing Record 4 of Set 5 | maxixe
# Processing Record 5 of Set 5 | whitehorse
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | seguela
# Processing Record 9 of Set 5 | half moon bay
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | bordighera
# Processing Record 12 of Set 5 | brazzaville
# Processing Record 13 of Set 5 | lhokseumawe
# Processing Record 14 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 5 | puerto del rosario
# Processing Record 16 of Set 5 | milkovo
# Processing Record 17 of Set 5 | kidal
# Processing Record 18 of Set 5 | sola
# Processing Record 19 of Set 5 | sechura
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | fairbanks
# Processing Record 22 of Set 5 | asau
# Processing Record 23 of Set 5 | ixtapa
# Processing Record 24 of Set 5 | mandalgovi
# Processing Record 25 of Set 5 | salinas
# Processing Record 26 of Set 5 | lasa
# Processing Record 27 of Set 5 | bayevo
# Processing Record 28 of Set 5 | rondonopolis
# Processing Record 29 of Set 5 | ucluelet
# Processing Record 30 of Set 5 | takoradi
# Processing Record 31 of Set 5 | auki
# Processing Record 32 of Set 5 | goderich
# Processing Record 33 of Set 5 | khatanga
# Processing Record 34 of Set 5 | vicosa do ceara
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | najran
# Processing Record 37 of Set 5 | iqaluit
# Processing Record 38 of Set 5 | behshahr
# Processing Record 39 of Set 5 | aras
# Processing Record 40 of Set 5 | port arthur
# Processing Record 41 of Set 5 | dolinsk
# Processing Record 42 of Set 5 | orissaare
# Processing Record 43 of Set 5 | okato
# Processing Record 44 of Set 5 | hays
# Processing Record 45 of Set 5 | nemuro
# Processing Record 46 of Set 5 | verkhniye tatyshly
# Processing Record 47 of Set 5 | trat
# Processing Record 48 of Set 5 | kaseda
# Processing Record 49 of Set 5 | susurluk
# Processing Record 50 of Set 5 | lethem
# Processing Record 1 of Set 6 | pohrebyshche
# Processing Record 2 of Set 6 | morant bay
# Processing Record 3 of Set 6 | puerto madryn
# Processing Record 4 of Set 6 | shiyan
# Processing Record 5 of Set 6 | hasaki
# Processing Record 6 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 6 | burnie
# Processing Record 8 of Set 6 | mar del plata
# Processing Record 9 of Set 6 | saint-pierre
# Processing Record 10 of Set 6 | qaanaaq
# Processing Record 11 of Set 6 | pangnirtung
# Processing Record 12 of Set 6 | ponta delgada
# Processing Record 13 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 6 | yerbogachen
# Processing Record 15 of Set 6 | winnemucca
# Processing Record 16 of Set 6 | martapura
# Processing Record 17 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 6 | santa vitoria do palmar
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | road town
# Processing Record 22 of Set 6 | bonfim
# Processing Record 23 of Set 6 | nizwa
# Processing Record 24 of Set 6 | omsukchan
# Processing Record 25 of Set 6 | mafra
# Processing Record 26 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 6 | hervey bay
# Processing Record 28 of Set 6 | polson
# Processing Record 29 of Set 6 | kahului
# Processing Record 30 of Set 6 | baracoa
# Processing Record 31 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 6 | san jose
# Processing Record 33 of Set 6 | nishihara
# Processing Record 34 of Set 6 | nyagan
# Processing Record 35 of Set 6 | grindavik
# Processing Record 36 of Set 6 | portales
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | deer lake
# Processing Record 39 of Set 6 | waipawa
# Processing Record 40 of Set 6 | mahebourg
# Processing Record 41 of Set 6 | hit
# Processing Record 42 of Set 6 | colares
# Processing Record 43 of Set 6 | zyryanka
# Processing Record 44 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | ersekvadkert
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | trairi
# Processing Record 50 of Set 6 | darovskoy
# Processing Record 1 of Set 7 | kandry
# Processing Record 2 of Set 7 | shingu
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | yithion
# City not found. Skipping...
# Processing Record 5 of Set 7 | champasak
# Processing Record 6 of Set 7 | thompson
# Processing Record 7 of Set 7 | mount vernon
# Processing Record 8 of Set 7 | sorong
# Processing Record 9 of Set 7 | zemio
# Processing Record 10 of Set 7 | the pas
# Processing Record 11 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 7 | atambua
# Processing Record 13 of Set 7 | harbour breton
# Processing Record 14 of Set 7 | hirara
# Processing Record 15 of Set 7 | burica
# City not found. Skipping...
# Processing Record 16 of Set 7 | prince albert
# Processing Record 17 of Set 7 | raga
# Processing Record 18 of Set 7 | namibe
# Processing Record 19 of Set 7 | portland
# Processing Record 20 of Set 7 | sabang
# Processing Record 21 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 7 | plyussa
# Processing Record 23 of Set 7 | dryden
# Processing Record 24 of Set 7 | pareora
# Processing Record 25 of Set 7 | bosobolo
# Processing Record 26 of Set 7 | te anau
# Processing Record 27 of Set 7 | leh
# Processing Record 28 of Set 7 | nabire
# Processing Record 29 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 7 | nhulunbuy
# Processing Record 31 of Set 7 | bambous virieux
# Processing Record 32 of Set 7 | merauke
# Processing Record 33 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 34 of Set 7 | birao
# Processing Record 35 of Set 7 | verkhnevilyuysk
# Processing Record 36 of Set 7 | mahibadhoo
# Processing Record 37 of Set 7 | dudinka
# Processing Record 38 of Set 7 | beringovskiy
# Processing Record 39 of Set 7 | hue
# Processing Record 40 of Set 7 | atikokan
# Processing Record 41 of Set 7 | grand gaube
# Processing Record 42 of Set 7 | visnes
# Processing Record 43 of Set 7 | upernavik
# Processing Record 44 of Set 7 | basco
# Processing Record 45 of Set 7 | narbonne
# Processing Record 46 of Set 7 | derzhavinsk
# Processing Record 47 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 7 | asahikawa
# Processing Record 49 of Set 7 | mandera
# Processing Record 50 of Set 7 | trelew
# Processing Record 1 of Set 8 | sept-iles
# Processing Record 2 of Set 8 | ketchikan
# Processing Record 3 of Set 8 | tiksi
# Processing Record 4 of Set 8 | kloulklubed
# Processing Record 5 of Set 8 | haines junction
# Processing Record 6 of Set 8 | podolinec
# Processing Record 7 of Set 8 | dawei
# Processing Record 8 of Set 8 | imeni poliny osipenko
# Processing Record 9 of Set 8 | olinda
# Processing Record 10 of Set 8 | mount gambier
# Processing Record 11 of Set 8 | kyshtovka
# Processing Record 12 of Set 8 | ngunguru
# Processing Record 13 of Set 8 | cap-aux-meules
# Processing Record 14 of Set 8 | coihueco
# Processing Record 15 of Set 8 | french harbor
# Processing Record 16 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 17 of Set 8 | nara
# Processing Record 18 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 8 | hovd
# Processing Record 20 of Set 8 | port hardy
# Processing Record 21 of Set 8 | labrea
# Processing Record 22 of Set 8 | dingle
# Processing Record 23 of Set 8 | longyearbyen
# Processing Record 24 of Set 8 | fairview
# Processing Record 25 of Set 8 | luderitz
# Processing Record 26 of Set 8 | pandan
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | zarand
# Processing Record 29 of Set 8 | haradok
# Processing Record 30 of Set 8 | zaltan
# Processing Record 31 of Set 8 | galveston
# Processing Record 32 of Set 8 | carmen
# Processing Record 33 of Set 8 | la ronge
# Processing Record 34 of Set 8 | vila
# Processing Record 35 of Set 8 | asyut
# Processing Record 36 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 8 | corinth
# Processing Record 38 of Set 8 | pincher creek
# Processing Record 39 of Set 8 | svetlogorsk
# Processing Record 40 of Set 8 | morogoro
# Processing Record 41 of Set 8 | taoudenni
# Processing Record 42 of Set 8 | belmonte
# Processing Record 43 of Set 8 | oyem
# Processing Record 44 of Set 8 | bogo
# Processing Record 45 of Set 8 | ahuimanu
# Processing Record 46 of Set 8 | proletariy
# Processing Record 47 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 48 of Set 8 | sinnamary
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | sinfra
# Processing Record 1 of Set 9 | coihaique
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | sarkand
# Processing Record 5 of Set 9 | kibaya
# Processing Record 6 of Set 9 | wawa
# Processing Record 7 of Set 9 | labuhan
# Processing Record 8 of Set 9 | poddorye
# Processing Record 9 of Set 9 | doctor juan leon mallorquin
# Processing Record 10 of Set 9 | sciacca
# Processing Record 11 of Set 9 | hengyang
# Processing Record 12 of Set 9 | vila franca do campo
# Processing Record 13 of Set 9 | rio gallegos
# Processing Record 14 of Set 9 | pocone
# Processing Record 15 of Set 9 | sitka
# Processing Record 16 of Set 9 | miri
# Processing Record 17 of Set 9 | tarn taran
# Processing Record 18 of Set 9 | aswan
# Processing Record 19 of Set 9 | mount pleasant
# Processing Record 20 of Set 9 | bambanglipuro
# Processing Record 21 of Set 9 | wuhu
# Processing Record 22 of Set 9 | coyuca
# City not found. Skipping...
# Processing Record 23 of Set 9 | amilly
# Processing Record 24 of Set 9 | leshukonskoye
# Processing Record 25 of Set 9 | siavonga
# Processing Record 26 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 27 of Set 9 | carnarvon
# Processing Record 28 of Set 9 | umm lajj
# Processing Record 29 of Set 9 | san rafael del sur
# Processing Record 30 of Set 9 | kaeo
# Processing Record 31 of Set 9 | tateyama
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | nuuk
# Processing Record 34 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 35 of Set 9 | spearfish
# Processing Record 36 of Set 9 | port hedland
# Processing Record 37 of Set 9 | quarai
# Processing Record 38 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 9 | konakovo
# Processing Record 40 of Set 9 | sovetskaya
# Processing Record 41 of Set 9 | asfi
# Processing Record 42 of Set 9 | pampierstad
# Processing Record 43 of Set 9 | yemelyanovo
# Processing Record 44 of Set 9 | acari
# Processing Record 45 of Set 9 | ulladulla
# Processing Record 46 of Set 9 | buldana
# Processing Record 47 of Set 9 | porbandar
# Processing Record 48 of Set 9 | maniitsoq
# Processing Record 49 of Set 9 | rocha
# Processing Record 50 of Set 9 | bilibino
# Processing Record 1 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 10 | nouadhibou
# Processing Record 3 of Set 10 | aksu
# Processing Record 4 of Set 10 | aloleng
# Processing Record 5 of Set 10 | hlatikulu
# Processing Record 6 of Set 10 | carbonear
# Processing Record 7 of Set 10 | atlixco
# Processing Record 8 of Set 10 | kavaratti
# Processing Record 9 of Set 10 | ternate
# Processing Record 10 of Set 10 | maicao
# Processing Record 11 of Set 10 | acarau
# Processing Record 12 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 10 | malindi
# Processing Record 14 of Set 10 | tabuk
# Processing Record 15 of Set 10 | mendoza
# Processing Record 16 of Set 10 | antofagasta
# Processing Record 17 of Set 10 | inongo
# Processing Record 18 of Set 10 | bardiyah
# Processing Record 19 of Set 10 | vanavara
# Processing Record 20 of Set 10 | kjollefjord
# Processing Record 21 of Set 10 | zhuhai
# Processing Record 22 of Set 10 | colombo
# Processing Record 23 of Set 10 | pentecoste
# Processing Record 24 of Set 10 | severo-yeniseyskiy
# Processing Record 25 of Set 10 | san vicente
# Processing Record 26 of Set 10 | yarmouth
# Processing Record 27 of Set 10 | sao filipe
# Processing Record 28 of Set 10 | nicoya
# Processing Record 29 of Set 10 | tomohon
# Processing Record 30 of Set 10 | tres arroyos
# Processing Record 31 of Set 10 | werda
# Processing Record 32 of Set 10 | fare
# Processing Record 33 of Set 10 | entre rios
# Processing Record 34 of Set 10 | lewistown
# Processing Record 35 of Set 10 | turan
# Processing Record 36 of Set 10 | tokur
# Processing Record 37 of Set 10 | mananara
# Processing Record 38 of Set 10 | tomatlan
# Processing Record 39 of Set 10 | chipinge
# Processing Record 40 of Set 10 | koumac
# Processing Record 41 of Set 10 | sao felix do xingu
# Processing Record 42 of Set 10 | honningsvag
# Processing Record 43 of Set 10 | egvekinot
# Processing Record 44 of Set 10 | orhangazi
# Processing Record 45 of Set 10 | laguna
# Processing Record 46 of Set 10 | eyl
# Processing Record 47 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 10 | noumea
# Processing Record 49 of Set 10 | lazaro cardenas
# Processing Record 50 of Set 10 | havoysund
# Processing Record 1 of Set 11 | maunabo
# Processing Record 2 of Set 11 | doha
# Processing Record 3 of Set 11 | totma
# Processing Record 4 of Set 11 | thunder bay
# Processing Record 5 of Set 11 | hurghada
# Processing Record 6 of Set 11 | channel-port aux basques
# Processing Record 7 of Set 11 | irshava
# Processing Record 8 of Set 11 | saiha
# Processing Record 9 of Set 11 | majene
# Processing Record 10 of Set 11 | maues
# Processing Record 11 of Set 11 | gander
# Processing Record 12 of Set 11 | isangel
# Processing Record 13 of Set 11 | maumere
# Processing Record 14 of Set 11 | coahuayana
# Processing Record 15 of Set 11 | kieta
# Processing Record 16 of Set 11 | farafenni
# Processing Record 17 of Set 11 | kodinsk
# Processing Record 18 of Set 11 | tokat
# Processing Record 19 of Set 11 | jalalpur pirwala
# Processing Record 20 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 11 | tilichiki
# Processing Record 22 of Set 11 | amapa
# Processing Record 23 of Set 11 | acapulco
# Processing Record 24 of Set 11 | constitucion
# Processing Record 25 of Set 11 | zambezi
# Processing Record 26 of Set 11 | porto santo
# Processing Record 27 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 11 | manbij
# Processing Record 29 of Set 11 | sorland
# Processing Record 30 of Set 11 | ustynivka
# Processing Record 31 of Set 11 | berlevag
# Processing Record 32 of Set 11 | ginir
# Processing Record 33 of Set 11 | puerto baquerizo moreno
# Processing Record 34 of Set 11 | saint-joseph
# Processing Record 35 of Set 11 | naantali
# Processing Record 36 of Set 11 | arlit
# Processing Record 37 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 11 | the valley
# Processing Record 39 of Set 11 | novyy urengoy
# Processing Record 40 of Set 11 | dali
# Processing Record 41 of Set 11 | umea
# Processing Record 42 of Set 11 | eufaula
# Processing Record 43 of Set 11 | behbahan
# Processing Record 44 of Set 11 | black river
# Processing Record 45 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 11 | kerrville
# Processing Record 47 of Set 11 | ossora
# Processing Record 48 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 11 | gat
# Processing Record 50 of Set 11 | darhan
# Processing Record 1 of Set 12 | clarence town
# Processing Record 2 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 12 | gasa
# Processing Record 4 of Set 12 | inhuma
# Processing Record 5 of Set 12 | kavieng
# Processing Record 6 of Set 12 | chissamba
# Processing Record 7 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 8 of Set 12 | chippewa falls
# Processing Record 9 of Set 12 | sohbatpur
# Processing Record 10 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 12 | chicama
# Processing Record 12 of Set 12 | kapiri mposhi
# Processing Record 13 of Set 12 | santa cruz
# Processing Record 14 of Set 12 | victor harbor
# Processing Record 15 of Set 12 | el alto
# Processing Record 16 of Set 12 | la seyne-sur-mer
# Processing Record 17 of Set 12 | papara
# Processing Record 18 of Set 12 | korla
# Processing Record 19 of Set 12 | kalmar
# Processing Record 20 of Set 12 | anadyr
# Processing Record 21 of Set 12 | muramatsu
# Processing Record 22 of Set 12 | zheleznodorozhnyy
# Processing Record 23 of Set 12 | lagoa
# Processing Record 24 of Set 12 | makakilo city
# Processing Record 25 of Set 12 | jacksonville
# Processing Record 26 of Set 12 | muros
# Processing Record 27 of Set 12 | claresholm
# Processing Record 28 of Set 12 | basudebpur
# Processing Record 29 of Set 12 | langenau
# Processing Record 30 of Set 12 | robore
# Processing Record 31 of Set 12 | baykit
# Processing Record 32 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 12 | marawi
# Processing Record 34 of Set 12 | touros
# Processing Record 35 of Set 12 | severodvinsk
# Processing Record 36 of Set 12 | batagay
# Processing Record 37 of Set 12 | nalut
# Processing Record 38 of Set 12 | san juan
# Processing Record 39 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 12 | saint-georges
# Processing Record 41 of Set 12 | athmallik
# Processing Record 42 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 12 | tecoanapa
# Processing Record 44 of Set 12 | tukrah
# Processing Record 45 of Set 12 | svetlyy
# Processing Record 46 of Set 12 | klaksvik
# Processing Record 47 of Set 12 | wonthaggi
# Processing Record 48 of Set 12 | sharjah
# Processing Record 49 of Set 12 | ngerengere
# Processing Record 50 of Set 12 | lahij
# Processing Record 1 of Set 13 | nambucca heads
# Processing Record 2 of Set 13 | rio casca
# Processing Record 3 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 4 of Set 13 | luau
# Processing Record 5 of Set 13 | roebourne
# Processing Record 6 of Set 13 | anloga
# Processing Record 7 of Set 13 | jalu
# Processing Record 8 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 9 of Set 13 | roura
# Processing Record 10 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 11 of Set 13 | teknaf
# Processing Record 12 of Set 13 | meadow lake
# Processing Record 13 of Set 13 | ramsgate
# Processing Record 14 of Set 13 | taltal
# Processing Record 15 of Set 13 | alamosa
# Processing Record 16 of Set 13 | aksarayskiy
# Processing Record 17 of Set 13 | ust-ishim
# Processing Record 18 of Set 13 | zamora
# Processing Record 19 of Set 13 | lobatse
# Processing Record 20 of Set 13 | beaverlodge
# Processing Record 21 of Set 13 | sydney
# Processing Record 22 of Set 13 | altay
# Processing Record 23 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 13 | camana
# Processing Record 25 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 13 | northam
# Processing Record 27 of Set 13 | poltar
# Processing Record 28 of Set 13 | manta
# Processing Record 29 of Set 13 | sibolga
# Processing Record 30 of Set 13 | ostersund
# Processing Record 31 of Set 13 | krasnoselkup
# Processing Record 32 of Set 13 | ahipara
# Processing Record 33 of Set 13 | malanje
# Processing Record 34 of Set 13 | liaocheng
# Processing Record 35 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 36 of Set 13 | beira
# Processing Record 37 of Set 13 | esso
# Processing Record 38 of Set 13 | saravan
# Processing Record 39 of Set 13 | melito di porto salvo
# Processing Record 40 of Set 13 | zihuatanejo
# Processing Record 41 of Set 13 | solwezi
# Processing Record 42 of Set 13 | yerofey pavlovich
# Processing Record 43 of Set 13 | puri
# Processing Record 44 of Set 13 | peniche
# Processing Record 45 of Set 13 | meulaboh
# Processing Record 46 of Set 13 | dumas
# Processing Record 47 of Set 13 | parana
# Processing Record 48 of Set 13 | montrose
# Processing Record 49 of Set 13 | benghazi
# Processing Record 50 of Set 13 | sun city west
# Processing Record 1 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 14 | butia
# Processing Record 3 of Set 14 | fort nelson
# Processing Record 4 of Set 14 | honggang
# Processing Record 5 of Set 14 | kemin
# Processing Record 6 of Set 14 | killybegs
# Processing Record 7 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 14 | mezen
# Processing Record 9 of Set 14 | wana
# Processing Record 10 of Set 14 | anzio
# Processing Record 11 of Set 14 | tabou
# Processing Record 12 of Set 14 | comodoro rivadavia
# Processing Record 13 of Set 14 | el jicaro
# Processing Record 14 of Set 14 | sao joao da barra
# Processing Record 15 of Set 14 | adre
# Processing Record 16 of Set 14 | houma
# Processing Record 17 of Set 14 | valdivia
# Processing Record 18 of Set 14 | ormara
# Processing Record 19 of Set 14 | katsuura
# Processing Record 20 of Set 14 | kudahuvadhoo
# Processing Record 21 of Set 14 | ligayan
# Processing Record 22 of Set 14 | lima
# Processing Record 23 of Set 14 | fengcheng
# Processing Record 24 of Set 14 | mehamn
# Processing Record 25 of Set 14 | saint-leu
# Processing Record 26 of Set 14 | lloret de mar
# Processing Record 27 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 14 | aljezur
# Processing Record 29 of Set 14 | shetpe
# Processing Record 30 of Set 14 | makokou
# Processing Record 31 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 14 | omboue
# Processing Record 33 of Set 14 | riyadh
# Processing Record 34 of Set 14 | bani walid
# Processing Record 35 of Set 14 | sakaraha
# Processing Record 36 of Set 14 | philadelphia
# Processing Record 37 of Set 14 | barcelos
# Processing Record 38 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 14 | hambantota
# Processing Record 40 of Set 14 | karaman
# Processing Record 41 of Set 14 | magistralnyy
# Processing Record 42 of Set 14 | hereford
# Processing Record 43 of Set 14 | ajnala
# Processing Record 44 of Set 14 | karpathos
# Processing Record 45 of Set 14 | almaznyy
# Processing Record 46 of Set 14 | mnogovershinnyy
# Processing Record 47 of Set 14 | garowe
# Processing Record 48 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 49 of Set 14 | harper
# Processing Record 50 of Set 14 | boyolangu
# Processing Record 1 of Set 15 | richards bay
# Processing Record 2 of Set 15 | atagay
# Processing Record 3 of Set 15 | cayenne
# Processing Record 4 of Set 15 | sretensk
# Processing Record 5 of Set 15 | fasa
# Processing Record 6 of Set 15 | paciran
# Processing Record 7 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 15 | ranong
# Processing Record 9 of Set 15 | nagato
# Processing Record 10 of Set 15 | bose
# Processing Record 11 of Set 15 | umm kaddadah
# Processing Record 12 of Set 15 | belyy yar
# Processing Record 13 of Set 15 | halvad
# Processing Record 14 of Set 15 | pombas
# Processing Record 15 of Set 15 | shizunai
# Processing Record 16 of Set 15 | hvolsvollur
# Processing Record 17 of Set 15 | saint-esteve
# Processing Record 18 of Set 15 | sialkot
# Processing Record 19 of Set 15 | marumori
# Processing Record 20 of Set 15 | talaya
# Processing Record 21 of Set 15 | kurilsk
# Processing Record 22 of Set 15 | dalby
# Processing Record 23 of Set 15 | nome
# Processing Record 24 of Set 15 | harer
# Processing Record 25 of Set 15 | mitsamiouli
# Processing Record 26 of Set 15 | gorodishche
# Processing Record 27 of Set 15 | disna
# Processing Record 28 of Set 15 | esterhazy
# Processing Record 29 of Set 15 | adrar
# Processing Record 30 of Set 15 | tombouctou
# Processing Record 31 of Set 15 | young
# Processing Record 32 of Set 15 | superior
# Processing Record 33 of Set 15 | khovu-aksy
# Processing Record 34 of Set 15 | kruisfontein
# Processing Record 35 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 15 | dunn
# Processing Record 37 of Set 15 | camacupa
# Processing Record 38 of Set 15 | dovers
# Processing Record 39 of Set 15 | maibong
# Processing Record 40 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 41 of Set 15 | caxito
# Processing Record 42 of Set 15 | plastun
# Processing Record 43 of Set 15 | rio tercero
# Processing Record 44 of Set 15 | roald
# Processing Record 45 of Set 15 | abha
# Processing Record 46 of Set 15 | aasiaat
# Processing Record 47 of Set 15 | salym
# Processing Record 48 of Set 15 | tainan
# Processing Record 49 of Set 15 | huatulco
# Processing Record 50 of Set 15 | gizo
# Processing Record 1 of Set 16 | prattville
# Processing Record 2 of Set 16 | cockburn town
# Processing Record 3 of Set 16 | komsomolskiy
# Processing Record 4 of Set 16 | taburao
# City not found. Skipping...
# Processing Record 5 of Set 16 | kasra
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Zhanjiang      CN  21.2815  110.3427     81.95        87         100
# 1       Cape Town      ZA -33.9258   18.4232     58.87        90          90
# 2            Lata      PT  40.1629   -8.3327     74.35        37           0
# 3         Lianran      CN  24.9227  102.4850     72.14        88          81
# 4  Treinta Y Tres      UY -33.2333  -54.3833     34.36        86           7
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1        3.00          light rain
# 2        6.69           clear sky
# 3        1.34          light rain
# 4        7.94           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-9-459e5c6df311> in <module>
#       2 output_data_file = "WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#       5 # Ask the customer to add a minimum and maximum temperature value.
#       6 min_temp = float(input("What is the minimum temperature you would like for your trip? "))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'WeatherPy_Database.csv'
